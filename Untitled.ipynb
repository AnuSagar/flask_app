# %%
from get_user_status import *
from latest_mumbai_zones import get_latest_data
from geocode_batch import geocode

# %%
#Scrape latest Mumbai Data
df1,df2 = get_latest_data()
# Out:
# -------Crawling mcgm.gov for latest zones update-----------
# ----------Data Extracted -----------

# %%
All_file = df1.append(df2).reset_index(drop=True)

# %%
All_file.to_csv('mumbai_address.csv',index=False)

# %%
geo_df1 = geocode(All_file[All_file.pin=='400002'])

# %%
geo_df1.head()
# Out:
#      city confidenceScore         district    eLoc  \
# 0  Mumbai             0.8  Mumbai District  5EC7LB
# 1  Mumbai               1  Mumbai District  TSE514
# 2  Mumbai             0.4  Mumbai District  B79XRX
# 3  Mumbai               1  Mumbai District  FL8ZQE
# 4  Mumbai               1  Mumbai District  400002
#
#                                     formattedAddress geocodeLevel houseName  \
# 0  Zaveri Bazar, Shaikh Memon Street, Zaveri Baza...          poi
# 1  Mumbai Bar, Kalbadevi Road, Kalbadevi, Mumbai,...      pincode
# 2  C, Mangaldas Road, Lohar Chawl, Mumbai, Mumbai...  houseNumber
# 3  Marine Lines, Mumbai, Mumbai District, Mumbai,...     locality
# 4       Mumbai District, Mumbai, Maharashtra, 400002      pincode
#
#   houseNumber latitude      locality longitude pincode           poi  \
# 0              18.9515     Kalbadevi   72.8306  400002  Zaveri Bazar
# 1              18.9458     Kalbadevi   72.8293  400002    Mumbai Bar
# 2           C  18.9463   Lohar Chawl   72.8318  400002
# 3              18.9441  Marine Lines   72.8232  400002
# 4                18.95                 72.8257  400002
#
#          state               street subDistrict   subLocality subSubLocality  \
# 0  Maharashtra  Shaikh Memon Street      Mumbai  Zaveri Bazar
# 1  Maharashtra       Kalbadevi Road      Mumbai
# 2  Maharashtra       Mangaldas Road      Mumbai
# 3  Maharashtra                           Mumbai
# 4  Maharashtra
#
#   village
# 0
# 1
# 2
# 3
# 4

# %%
address = 'Allana Rd, Kala Ghoda fort, mumbai 400001'
get_user_add_status(address)

# %%
import dash
from get_user_status import *
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Output, State, Input

if __name__ == '__main__':
    app = dash.Dash()

    app.layout = html.Div([
        dcc.Input(id='username', value='Address', type='text'),
        html.Button(id='submit-button', type='submit', children='Submit'),
        html.Div(id='output_div')
    ])

    @app.callback(Output('output_div', 'children'),
                  [Input('submit-button', 'n_clicks')],
                  [State('username', 'value')],
                  )
    def update_output(clicks, input_value):
        if clicks is not None:
            text = get_user_add_status(input_value)
            #text = '   kjfvskjnc,as' + input_value
            return(text)

    app.run_server(debug=True, use_reloader=False)

# %%
import dash
from dash.dependencies import Input, Output,State
import dash_html_components as html
import dash_core_components as dcc
from get_user_status import *
app = dash.Dash(__name__)

app.layout = html.Div([
    dcc.Textarea(
        id='textarea-example',
        value='Textarea content initialized\nwith multiple lines of text',
        style={'width': '20%', 'height': 100},
    ),
    html.Button(id='submit-button', type='submit', children='Submit'),
    html.Div(id='textarea-example-output', style={'whiteSpace': 'pre-line'}),
     
        
])

@app.callback(
    Output('textarea-example-output', 'children'),
    [Input('submit-button', 'n_clicks')],
    [State('textarea-example', 'value')],
)

def update_output(clicks, input_value):
    if clicks is not None:
        text = get_user_add_status(input_value)
        
        return(text)


if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False)
# Out:
# Running on http://127.0.0.1:8050/
# Running on http://127.0.0.1:8050/
# Running on http://127.0.0.1:8050/
# Debugger PIN: 425-339-267
# Debugger PIN: 425-339-267
# Debugger PIN: 425-339-267
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# user address

# %%
 @app.callback(Output('output_div', 'children'),
                  [Input('submit-button', 'n_clicks')],
                  [State('username', 'value')],
                  )
